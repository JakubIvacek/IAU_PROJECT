# %% [markdown]
# # 2.Fáza Predspracovanie dát

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler, QuantileTransformer, PowerTransformer, RobustScaler

# %%
connections = pd.read_csv('data/connections.csv', 
                   sep='\t', 
                   header=0)
connections.head(10)
# Out:
#                     ts                 imei  mwra  c.katana  c.android.gm  \
# 0  2018-05-05 10:00:00   359043379931766452   0.0  11.06115      12.03060
# 1  2018-05-05 10:01:00  3590433799317661479   1.0  10.36927      13.33058
# 2  2018-05-05 10:02:00   863033069630348941   1.0  11.13179      11.55974
# 3  2018-05-05 10:03:00   863033069630348891   0.0  18.55737       7.52229
# 4  2018-05-05 10:04:00   863033069630348982   1.0  16.23621       6.46232
# 5  2018-05-05 10:05:00   359043379931766890   0.0  12.65449      11.31760
# 6  2018-05-05 10:06:00  8630330696303482394   1.0   7.51715       9.71631
# 7  2018-05-05 10:07:00  8630330696303481552   1.0  10.42239      11.16408
# 8  2018-05-05 10:08:00  8630330696303482410   0.0  16.96537       7.81786
# 9  2018-05-05 10:09:00  8630330696303481289   0.0  11.72449      10.31466
#
#    c.dogalize  c.android.chrome  c.android.youtube  c.raider  \
# 0     9.91193          11.61488           14.41566   0.00630
# 1    10.47183           5.81122           13.42850   0.00335
# 2    10.19114           9.48536           11.48909   0.00687
# 3     9.76952          10.09019            8.59293  11.20737
# 4    14.43755          10.06295            7.56208   1.10024
# 5    12.80750           7.63353            6.94398   0.03072
# 6    11.16790          14.25744           11.86472   0.00040
# 7    15.36993          12.40764           15.72517   0.00342
# 8    11.74992           8.24555           13.41690   2.28102
# 9     7.08285           9.68121           13.50829   0.01218
#
#    c.android.vending  c.UCMobile.x86  c.updateassist  c.UCMobile.intl
# 0           50.61159        59.89217        10.61973         29.26605
# 1           42.15179        33.30329        37.55184         79.39223
# 2           31.98880        57.96025        98.36767         67.51165
# 3           63.24643        68.14477         1.25216         70.80992
# 4           52.21213        62.91701        39.23750          4.40841
# 5           46.84296        72.10419        65.21307         53.36385
# 6           55.64279        51.34929        11.43310         93.70164
# 7           39.94261        78.25351        78.85671         51.24171
# 8           51.88202        51.86428        77.53953         71.13616
# 9           41.56365        63.83457        63.27459          1.02142

# %%
processes = pd.read_csv('data/processes.csv', 
                   sep='\t', 
                   header=0)
processes.head(10)
# Out:
#                     ts                 imei  mwra  p.android.gm  \
# 0  2018-05-05 10:00:00   359043379931766452   0.0       4.76403
# 1  2018-05-05 10:01:00  3590433799317661479   1.0      11.46891
# 2  2018-05-05 10:02:00   863033069630348941   1.0      14.17447
# 3  2018-05-05 10:03:00   863033069630348891   0.0      13.24902
# 4  2018-05-05 10:04:00   863033069630348982   1.0      10.03368
# 5  2018-05-05 10:05:00   359043379931766890   0.0      12.10487
# 6  2018-05-05 10:06:00  8630330696303482394   1.0      11.20547
# 7  2018-05-05 10:07:00  8630330696303481552   1.0       9.43152
# 8  2018-05-05 10:08:00  8630330696303482410   0.0       9.40552
# 9  2018-05-05 10:09:00  8630330696303481289   0.0       7.14433
#
#    p.android.chrome  p.android.packageinstaller  p.android.externalstorage  \
# 0          10.88071                    11.51360                   11.78927
# 1           8.28988                     7.09764                   13.77786
# 2          10.60933                    10.48707                   11.42372
# 3          12.97128                    14.07949                   12.04242
# 4           9.47160                     8.07917                   14.44551
# 5           7.06790                    10.77449                   11.54052
# 6          13.54670                     6.01785                   13.97898
# 7          11.19937                    10.16669                   13.59798
# 8          11.05332                    10.70500                   12.36928
# 9          11.25230                    14.82949                   14.69164
#
#    p.android.settings  p.android.documentsui  p.system  ...  \
# 0             9.99354                6.87053  13.51346  ...
# 1            15.06889               12.69941  12.31459  ...
# 2            12.21700               15.63323  10.68789  ...
# 3            15.05862               14.44617  13.38765  ...
# 4            15.64555                8.80989   7.84002  ...
# 5            13.25847                8.67721   8.88003  ...
# 6             9.35211                8.64164  14.59811  ...
# 7            12.60449               14.07398  15.60397  ...
# 8            11.72829               12.71607  11.03679  ...
# 9            13.77117               11.75249  10.76002  ...
#
#    p.inputmethod.latin  p.katana  p.process.gapps  p.browser.provider  \
# 0             79.29044  10.79383         83.63731             6.32371
# 1             45.98593  99.59445         98.05942             7.98917
# 2             80.90579  39.15136         35.96190            39.82428
# 3             73.85500  85.74165         89.95390            23.31018
# 4             19.27745  26.95881         61.93643            71.64654
# 5             63.77575  66.61781         32.08551            48.18337
# 6             62.71154   6.37995         49.26883            14.26143
# 7             68.55050  74.45278         46.79925            99.01885
# 8             80.48845  68.66819         78.93986            70.78193
# 9             28.58429  11.06029         92.74713            92.41559
#
#    p.gms.persistent  p.android.vending  p.notifier  p.simulator  p.dogalize  \
# 0          98.02549           68.85903    71.53462      2.25715    93.42594
# 1          95.75324           84.32885    28.67616     33.34162    74.46069
# 2          23.28994           11.66910    73.73339     94.80023    29.08949
# 3          85.76856           83.81530    77.31641     77.72672    82.13086
# 4          85.38242           49.78533    37.98503     90.32310    39.01098
# 5          34.87881           99.56064    23.62307     23.62557    30.64260
# 6          35.61887           99.91404    78.01157      0.10921    85.78794
# 7          12.66284           62.62353    22.11113      9.42886    74.13334
# 8           4.54058            3.58426    84.71937     40.42517    54.45794
# 9          40.25147           33.18383    59.26034     77.34647    32.94507
#
#    p.android.defcontainer
# 0                21.75571
# 1                50.49767
# 2                53.56893
# 3                77.27342
# 4                 5.83207
# 5                16.19268
# 6                 3.44839
# 7                84.01403
# 8                30.66241
# 9                63.39220
#
# [10 rows x 23 columns]

# %% [markdown]
# ### Ocistenie dat

# %%
# Odstranenie duplicit
connections.drop_duplicates( inplace=True)
processes.drop_duplicates(inplace=True)

# %%
# Spojenie tabuliek Connections a Processes podla imei a ts
df = pd.merge(connections, processes, on=['imei', 'ts','mwra'], how='outer')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14978 entries, 0 to 14977
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ts                          14978 non-null  object
#  1   imei                        14978 non-null  int64
#  2   mwra                        14978 non-null  float64
#  3   c.katana                    14978 non-null  float64
#  4   c.android.gm                14978 non-null  float64
#  5   c.dogalize                  14978 non-null  float64
#  6   c.android.chrome            14978 non-null  float64
#  7   c.android.youtube           14978 non-null  float64
#  8   c.raider                    14978 non-null  float64
#  9   c.android.vending           14978 non-null  float64
#  10  c.UCMobile.x86              14978 non-null  float64
#  11  c.updateassist              14978 non-null  float64
#  12  c.UCMobile.intl             14978 non-null  float64
#  13  p.android.gm                14978 non-null  float64
#  14  p.android.chrome            14978 non-null  float64
#  15  p.android.packageinstaller  14978 non-null  float64
#  16  p.android.externalstorage   14978 non-null  float64
#  17  p.android.settings          14978 non-null  float64
#  18  p.android.documentsui       14978 non-null  float64
#  19  p.system                    14978 non-null  float64
#  20  p.google                    14978 non-null  float64
#  21  p.android.gms               14978 non-null  float64
#  22  p.olauncher                 14978 non-null  float64
#  23  p.inputmethod.latin         14978 non-null  float64
#  24  p.katana                    14978 non-null  float64
#  25  p.process.gapps             14978 non-null  float64
#  26  p.browser.provider          14978 non-null  float64
#  27  p.gms.persistent            14978 non-null  float64
#  28  p.android.vending           14978 non-null  float64
#  29  p.notifier                  14978 non-null  float64
#  30  p.simulator                 14978 non-null  float64
#  31  p.dogalize                  14978 non-null  float64
#  32  p.android.defcontainer      14978 non-null  float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 3.8+ MB

# %% [markdown]
# #### Vybrali sme tabulky Connections a Processes s ktorými budeme dalej pokračovať pretože podla nas stacia na predikovanie mrwa. Tabulky Devices a Profiles dalej nebudeme podla nas potrebovat

# %% [markdown]
# ## 2.1 Realizácia a predspracovanie dát
# ### (A-1b) Dáta si rozdeľte na trénovaciu a testovaciu množinu podľa vami preddefinovaného pomeru. Ďalej pracujte len s trénovacím datasetom.

# %%
x = df.drop(columns='mwra')
y = df['mwra']

# %%
x_train, x_test, y_train, y_test =  train_test_split(x, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### (B-1b) Transformujte dáta na vhodný formát pre ML t.j. jedno pozorovanie musí byť opísané jedným riadkom a každý atribút musí byť v numerickom formáte (encoding). zIteratívne integrujte aj kroky v predspracovaní dát z prvej fázy (missing values, outlier detection) ako celok.

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11982 entries, 4828 to 13349
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ts                          11982 non-null  object
#  1   imei                        11982 non-null  int64
#  2   c.katana                    11982 non-null  float64
#  3   c.android.gm                11982 non-null  float64
#  4   c.dogalize                  11982 non-null  float64
#  5   c.android.chrome            11982 non-null  float64
#  6   c.android.youtube           11982 non-null  float64
#  7   c.raider                    11982 non-null  float64
#  8   c.android.vending           11982 non-null  float64
#  9   c.UCMobile.x86              11982 non-null  float64
#  10  c.updateassist              11982 non-null  float64
#  11  c.UCMobile.intl             11982 non-null  float64
#  12  p.android.gm                11982 non-null  float64
#  13  p.android.chrome            11982 non-null  float64
#  14  p.android.packageinstaller  11982 non-null  float64
#  15  p.android.externalstorage   11982 non-null  float64
#  16  p.android.settings          11982 non-null  float64
#  17  p.android.documentsui       11982 non-null  float64
#  18  p.system                    11982 non-null  float64
#  19  p.google                    11982 non-null  float64
#  20  p.android.gms               11982 non-null  float64
#  21  p.olauncher                 11982 non-null  float64
#  22  p.inputmethod.latin         11982 non-null  float64
#  23  p.katana                    11982 non-null  float64
#  24  p.process.gapps             11982 non-null  float64
#  25  p.browser.provider          11982 non-null  float64
#  26  p.gms.persistent            11982 non-null  float64
#  27  p.android.vending           11982 non-null  float64
#  28  p.notifier                  11982 non-null  float64
#  29  p.simulator                 11982 non-null  float64
#  30  p.dogalize                  11982 non-null  float64
#  31  p.android.defcontainer      11982 non-null  float64
# dtypes: float64(30), int64(1), object(1)
# memory usage: 3.0+ MB

# %% [markdown]
# #### Vsetky data su v ciselnej reprezentácií okrem `ts` ktorý zmenime na typ datetime

# %%
x_train['ts'] = pd.to_datetime(x_train['ts'], format='%Y-%m-%d %H:%M:%S')

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11982 entries, 4828 to 13349
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ts                          11982 non-null  datetime64[ns]
#  1   imei                        11982 non-null  int64
#  2   c.katana                    11982 non-null  float64
#  3   c.android.gm                11982 non-null  float64
#  4   c.dogalize                  11982 non-null  float64
#  5   c.android.chrome            11982 non-null  float64
#  6   c.android.youtube           11982 non-null  float64
#  7   c.raider                    11982 non-null  float64
#  8   c.android.vending           11982 non-null  float64
#  9   c.UCMobile.x86              11982 non-null  float64
#  10  c.updateassist              11982 non-null  float64
#  11  c.UCMobile.intl             11982 non-null  float64
#  12  p.android.gm                11982 non-null  float64
#  13  p.android.chrome            11982 non-null  float64
#  14  p.android.packageinstaller  11982 non-null  float64
#  15  p.android.externalstorage   11982 non-null  float64
#  16  p.android.settings          11982 non-null  float64
#  17  p.android.documentsui       11982 non-null  float64
#  18  p.system                    11982 non-null  float64
#  19  p.google                    11982 non-null  float64
#  20  p.android.gms               11982 non-null  float64
#  21  p.olauncher                 11982 non-null  float64
#  22  p.inputmethod.latin         11982 non-null  float64
#  23  p.katana                    11982 non-null  float64
#  24  p.process.gapps             11982 non-null  float64
#  25  p.browser.provider          11982 non-null  float64
#  26  p.gms.persistent            11982 non-null  float64
#  27  p.android.vending           11982 non-null  float64
#  28  p.notifier                  11982 non-null  float64
#  29  p.simulator                 11982 non-null  float64
#  30  p.dogalize                  11982 non-null  float64
#  31  p.android.defcontainer      11982 non-null  float64
# dtypes: datetime64[ns](1), float64(30), int64(1)
# memory usage: 3.0 MB

# %% [markdown]
# #### Detekcia vychýlenych hodnôt

# %%
def identify_outliers(a):
    lower = a.quantile(0.25) - 1.5 * stats.iqr(a)
    upper = a.quantile(0.75) + 1.5 * stats.iqr(a)

    return a[(a > upper) | (a < lower)]

# %%
def filter_outliers(df,column,action):
    outliers = identify_outliers(df[column])
    if action == 'delete':
        df.drop(index=outliers.index,inplace=True)
    elif action == 'replace':
        lower_bound = df[column].quantile(0.05)
        upper_bound = df[column].quantile(0.95)

        df[column] = np.where(
            df[column] < lower_bound, lower_bound,
            np.where(df[column] > upper_bound, upper_bound, df[column])
        )

# %%
numeric_columns = [col for col in x_train.columns if col not in ['imei', 'ts']]

num_cols = len(numeric_columns)
fig, axes = plt.subplots(nrows=num_cols // 3 + 1, ncols=3, figsize=(15, num_cols * 2))
axes = axes.flatten()

for i, col in enumerate(numeric_columns):
    axes[i].hist(x_train[col].dropna(), bins=30, edgecolor='black')
    axes[i].set_title(col)

for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %%
numeric_columns = x_train.columns
numeric_columns = [col for col in numeric_columns if col not in ['imei', 'mwra']]
    
plt.figure(figsize=(15, 8))
sns.boxplot(data=x_train[numeric_columns], orient='v')
plt.xticks(rotation=90)
plt.show()

# %%
x_train['c.katana'].plot.hist(bins=50, xlabel="c.katana")
plt.show()

# %%
x_train.boxplot(column='c.katana', patch_artist=True, boxprops=dict(facecolor='red'))
# Out:
# <Axes: >

# %%
filter_outliers(x_train,'c.katana',action='delete')

# %%
x_train.boxplot(column='c.katana', patch_artist=True, boxprops=dict(facecolor='red'))
# Out:
# <Axes: >

# %%
x_train['c.katana'].plot.hist(bins=50, xlabel="c.katana")
plt.show()

# %%
columns_to_edit = [
    'c.android.gm', 'c.dogalize', 'c.android.chrome', 'c.android.youtube', 
    'c.katana', 'c.android.vending', 'c.UCMobile.x86', 'c.updateassist', 
    'c.UCMobile.intl', 'p.android.gm', 'p.android.chrome', 'p.android.packageinstaller', 
    'p.android.externalstorage', 'p.android.settings', 'p.android.documentsui', 
    'p.system', 'p.google', 'p.android.gms', 'p.olauncher'
]

for column in columns_to_edit:
    filter_outliers(x_train, column, action='delete')

# %%
numeric_columns = x_train.columns
numeric_columns = [col for col in numeric_columns if col not in ['imei', 'mwra']]
    
plt.figure(figsize=(15, 8))
sns.boxplot(data=x_train[numeric_columns], orient='v')
plt.xticks(rotation=90)
plt.show()

# %%
numeric_columns = [col for col in x_train.columns if col not in ['imei', 'ts']]

num_cols = len(numeric_columns)
fig, axes = plt.subplots(nrows=num_cols // 3 + 1, ncols=3, figsize=(15, num_cols * 2))
axes = axes.flatten()

for i, col in enumerate(numeric_columns):
    axes[i].hist(x_train[col].dropna(), bins=30, edgecolor='black')
    axes[i].set_title(col)

for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()

# %%
# Synchronizacia zaznamov x_train s y_train a reset indexov
y_train = y_train.loc[x_train.index]
x_train = x_train.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)

# %% [markdown]
# ### (C-2b) Transformujte atribúty dát pre strojové učenie podľa dostupných techník minimálne: scaling (2 techniky), transformers (2 techniky) a ďalšie. Cieľom je aby ste testovali efekty a vhodne kombinovali v dátovom pipeline (od časti 2.3 a v 3. fáze).

# %%
minmax = ['c.android.chrome', 'c.android.youtube']
quantile = ['c.raider']
power = ['p.android.settings']

# %% [markdown]
# #### Quantile Transformation

# %%
# Pouzijeme quantile transformation na c.raider pretože ma pravosklonne rozlozenie s extremnymi hodnotami
transformer_quantile = QuantileTransformer(output_distribution='normal', random_state=0)
x_train[quantile] = transformer_quantile.fit_transform(x_train[quantile])

# %% [markdown]
# #### Power Tranformation (Yeo-Johnson)

# %%
power_transformer = PowerTransformer(method='yeo-johnson')
x_train[power] = power_transformer.fit_transform(x_train[power])

# %% [markdown]
# #### MinMaxScaler

# %%
scaler_minmax = MinMaxScaler()
x_train[minmax] = scaler_minmax.fit_transform(x_train[minmax])

# %% [markdown]
# #### StandardScaler

# %%
# Na ostatne atributy netreba pouzit ziadne tranformacie pretoze data maju skoro normalne symetricke rozlozenie
# Takze pouzijeme len skalovanie okrem 'c.android.chrome', 'c.android.youtube' kde sme uz pouzili MinMax
scaler_standard = StandardScaler()
columns_to_scale = [col for col in x_train.columns if col not in minmax]
columns_to_scale = [col for col in columns_to_scale if col not in ['imei', 'ts']]
x_train[columns_to_scale] = scaler_standard.fit_transform(x_train[columns_to_scale])

# %% [markdown]
# ### (D-1b) Zdôvodnite Vaše voľby/rozhodnutie pre realizáciu (t.j. zdokumentovanie)

# %% [markdown]
# #### 1. Quantile Transformation - Sme použili na atribut c.raider pretože ma velmi lavosklonne rozdelenie s extremnými hodnotami bližiace sa 0. Quantile Transformation prerozdeli hodnoty aby sa podobali na normálne rozdelenie
# #### 2. Power Transformation - Tuto techniku sme sa rozhodli pouzit na atributy kt. maju pravosklonne alebo lavosklonne rozdelenie. Power Tranformation ich upravi tak aby boli viac symetrickejsie
# #### 3. MinMax Scaler - Kedže sme odstranili extremne hodnoty v predchádzajúcom kroku mozme pouzit MinMax Scaler kt. skaluje atributy tak aby spadali do intervali 0-1
# #### 4. StandardScaler - Kedze vacsina nasich atributov ma rozdelenie podobne normalnemu nepotrebujeme robit nejake transformacie ale upravit skalu atributov aby mali porovnatelny rozsah

# %% [markdown]
# ## 2.2 Výber atribútov pre strojové učenie (5b)
# ### (A-3b) Zistite, ktoré atribúty (features) vo vašich dátach pre ML sú informatívne k predikovanej premennej (minimálne 3 techniky s porovnaním medzi sebou).

# %%
spearman_corr = x_train.corrwith(y_train, method='spearman').sort_values(ascending=False)
top_spearman = spearman_corr.head(10)
top_spearman
# Out:
# c.android.youtube    0.555042
# c.android.chrome     0.300426
# p.system             0.288480
# c.android.gm         0.252855
# c.updateassist       0.019999
# c.UCMobile.intl      0.012227
# c.android.vending    0.010918
# p.android.chrome     0.010100
# p.process.gapps      0.009911
# p.gms.persistent     0.009576
# dtype: float64

# %%
pearson_corr = x_train.corrwith(y_train, method='pearson').sort_values(ascending=False)
top_pearson = pearson_corr.head(10)
top_pearson
# Out:
# c.android.youtube    0.550657
# p.system             0.308274
# c.android.chrome     0.291514
# c.android.gm         0.255791
# p.android.chrome     0.021285
# c.updateassist       0.020033
# c.UCMobile.intl      0.012195
# c.android.vending    0.010060
# p.process.gapps      0.009672
# p.gms.persistent     0.009614
# dtype: float64

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=1)
x_train_no_date = x_train.drop(columns=['ts'])  # Odstránenie dátového stĺpca pre Random Forest
rf.fit(x_train_no_date, y_train)
feature_importances = pd.Series(rf.feature_importances_, index=x_train_no_date.columns).sort_values(ascending=False)
top_rf = feature_importances.head(10)
top_rf
# Out:
# p.android.gm                  0.137083
# c.katana                      0.127095
# c.raider                      0.119216
# c.android.youtube             0.106243
# p.android.packageinstaller    0.047373
# p.system                      0.047208
# p.android.documentsui         0.034400
# c.android.chrome              0.033270
# c.android.gm                  0.032922
# c.dogalize                    0.029879
# dtype: float64

# %%
from sklearn.feature_selection import mutual_info_classif

# Výpočet vzájomnej informácie medzi atribútmi a cieľovou premennou
mutual_info = mutual_info_classif(x_train_no_date, y_train, random_state=1)
mutual_info_series = pd.Series(mutual_info, index=x_train_no_date.columns).sort_values(ascending=False)

top_mutual_info = mutual_info_series.head(10)
top_mutual_info
# Out:
# c.raider                      0.193099
# c.katana                      0.191397
# c.android.youtube             0.178217
# p.android.gm                  0.176691
# p.system                      0.068162
# p.android.settings            0.058452
# c.android.chrome              0.057635
# p.android.documentsui         0.055339
# p.android.packageinstaller    0.052159
# c.android.gm                  0.049758
# dtype: float64

# %%
comparison_df = pd.DataFrame({
    'RandomForest_Importance': top_rf,
    'Spearman_Correlation': top_spearman,
    'Pearson_Correlation': top_pearson,
    'Mutual_Information': top_mutual_info
})

# Zobrazenie tabuľky s top 10 atribútmi z každej metódy
comparison_df
# Out:
#                             RandomForest_Importance  Spearman_Correlation  \
# c.UCMobile.intl                                 NaN              0.012227
# c.android.chrome                           0.033270              0.300426
# c.android.gm                               0.032922              0.252855
# c.android.vending                               NaN              0.010918
# c.android.youtube                          0.106243              0.555042
# c.dogalize                                 0.029879                   NaN
# c.katana                                   0.127095                   NaN
# c.raider                                   0.119216                   NaN
# c.updateassist                                  NaN              0.019999
# p.android.chrome                                NaN              0.010100
# p.android.documentsui                      0.034400                   NaN
# p.android.gm                               0.137083                   NaN
# p.android.packageinstaller                 0.047373                   NaN
# p.android.settings                              NaN                   NaN
# p.gms.persistent                                NaN              0.009576
# p.process.gapps                                 NaN              0.009911
# p.system                                   0.047208              0.288480
#
#                             Pearson_Correlation  Mutual_Information
# c.UCMobile.intl                        0.012195                 NaN
# c.android.chrome                       0.291514            0.057635
# c.android.gm                           0.255791            0.049758
# c.android.vending                      0.010060                 NaN
# c.android.youtube                      0.550657            0.178217
# c.dogalize                                  NaN                 NaN
# c.katana                                    NaN            0.191397
# c.raider                                    NaN            0.193099
# c.updateassist                         0.020033                 NaN
# p.android.chrome                       0.021285                 NaN
# p.android.documentsui                       NaN            0.055339
# p.android.gm                                NaN            0.176691
# p.android.packageinstaller                  NaN            0.052159
# p.android.settings                          NaN            0.058452
# p.gms.persistent                       0.009614                 NaN
# p.process.gapps                        0.009672                 NaN
# p.system                               0.308274            0.068162

# %%
# Reset index pre porovnávaciu tabuľku
comparison_df = comparison_df.reset_index()

# Premaž stĺpec s indexom, aby sme mali "feature" ako stĺpec
comparison_df.rename(columns={'index': 'Feature'}, inplace=True)

# Vytvorenie grafu
plt.figure(figsize=(14, 8))
comparison_df.set_index('Feature').plot(kind='bar', alpha=0.7)
plt.title('Porovnanie významnosti atribútov')
plt.xlabel('Atribúty')
plt.ylabel('Významnosť / Korelácia')
plt.xticks(rotation=45)
plt.legend(title='Metóda', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### (B-1b) Zoraďte zistené atribúty v poradí podľa dôležitosti.

# %%
# Spojenie výsledkov do jedného dátového rámca
importance_df = pd.DataFrame({
    'Feature': comparison_df['Feature'],
    'RandomForest_Importance': comparison_df['RandomForest_Importance'],
    'Spearman_Correlation': comparison_df['Spearman_Correlation'],
    'Pearson_Correlation': comparison_df['Pearson_Correlation'],
    'Mutual_Information': comparison_df['Mutual_Information']
})

# Vyplnenie NaN hodnôt
importance_df.fillna(0, inplace=True)

# Spočítanie celkového skóre ako priemer významnosti a korelácií
importance_df['Total_Importance'] = (importance_df['RandomForest_Importance'] +
                                      importance_df['Spearman_Correlation'].abs() + 
                                      importance_df['Pearson_Correlation'].abs() + 
                                      importance_df['Mutual_Information']) / 4  # Teraz priemerujeme štyri hodnoty

# Zoradenie atribútov podľa celkového skóre
sorted_importance_df = importance_df.sort_values(by='Total_Importance', ascending=False)

# Zobrazenie výsledného zoradeného dátového rámca
print(sorted_importance_df[['Feature', 'Total_Importance']])
# Out:
#                        Feature  Total_Importance
# 4            c.android.youtube          0.347540
# 16                    p.system          0.178031
# 1             c.android.chrome          0.170711
# 2                 c.android.gm          0.147831
# 6                     c.katana          0.079623
# 11                p.android.gm          0.078443
# 7                     c.raider          0.078079
# 12  p.android.packageinstaller          0.024883
# 10       p.android.documentsui          0.022435
# 13          p.android.settings          0.014613
# 8               c.updateassist          0.010008
# 9             p.android.chrome          0.007846
# 5                   c.dogalize          0.007470
# 0              c.UCMobile.intl          0.006106
# 3            c.android.vending          0.005245
# 15             p.process.gapps          0.004896
# 14            p.gms.persistent          0.004797

# %% [markdown]
# ### (C-1b) Zdôvodnite Vaše voľby/rozhodnutie pre realizáciu (t.j. zdokumentovanie)

# %% [markdown]
# 1. Random Forest Feature Importance: Tento prístup je založený na modeloch založených na stromoch a poskytuje odhad dôležitosti atribútov
# 2. Pearsonova korelácia: Tento prístup je užitočný na posúdenie lineárneho vzťahu medzi atribútmi a cieľovou premennou
# 3. Spearmanova korelácia: Tento prístup sa zameriava na monotónne vzťahy, čím poskytuje alternatívu k Pearsonovej korelácii.
# 4. Vzájomná informácia: Tento prístup hodnotí, ako veľmi je informácia o cieľovej premennej obsiahnutá v atribúte.
# -- Znázornenie v tabuľke , grafom na pozorovanie hodnot
# ### (b)
# 1. Spojenie výsledkov do jedného dátového rámca a vyplnenie NaN hodnôt
# 2. Vyrátanie celkovej dôležitosti
# 3. Zoradenie a vypísanie výsledkov

# %% [markdown]
# ## 2.3 Replikovateľnosť predspracovania (5b)
# ### (A-3b) Upravte váš kód realizujúci predspracovanie trénovacej množiny tak, aby ho bolo možné bez ďalších úprav znovu použiť na predspracovanie testovacej množiny v kontexte strojového učenia.

# %% [markdown]
# ### (B-2b) Využite možnosti sklearn.pipeline

# %%
# Zaklad Pipeliny

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, MinMaxScaler, QuantileTransformer, PowerTransformer

# Identifikácia stĺpcov pre jednotlivé techniky
numerical_standard = ['c.android.gm', 'c.katana']          # Použijeme StandardScaler
numerical_minmax = ['c.android.chrome', 'c.android.youtube']  # Použijeme MinMaxScaler
numerical_quantile = ['c.raider', 'p.android.chrome']        # Použijeme QuantileTransformer
numerical_log = ['c.updateassist', 'p.android.settings']     # Použijeme PowerTransformer (Yeo-Johnson)

# Zoznam zvyšných stĺpcov, ktoré ponecháme bez úprav
remaining_columns = [col for col in x_train.columns if col not in numerical_standard + numerical_minmax + numerical_quantile + numerical_log]

# Pipeline pre jednotlivé techniky
standard_pipeline = Pipeline([
    ('scaler', StandardScaler())
])

minmax_pipeline = Pipeline([
    ('scaler', MinMaxScaler())
])

quantile_pipeline = Pipeline([
    ('quantile', QuantileTransformer(output_distribution='normal'))
])

log_pipeline = Pipeline([
    ('log', PowerTransformer(method='yeo-johnson'))
])

# Vytvorenie ColumnTransformer pre všetky atribúty
preprocessor = ColumnTransformer([
    ('standard', standard_pipeline, numerical_standard),
    ('minmax', minmax_pipeline, numerical_minmax),
    ('quantile', quantile_pipeline, numerical_quantile),
    ('log', log_pipeline, numerical_log)
], remainder='passthrough')  # Zvyšné stĺpce sa prenesú bez úprav

# Aplikácia pipeline na x_train
x_train_transformed = preprocessor.fit_transform(x_train)

# Konverzia na DataFrame pre lepšiu čitateľnosť výsledku
all_columns = numerical_standard + numerical_minmax + numerical_quantile + numerical_log + remaining_columns
x_train_transformed = pd.DataFrame(x_train_transformed, columns=all_columns)

x_train_transformed.head()
